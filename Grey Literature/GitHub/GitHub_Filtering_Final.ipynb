# %%
import pandas as pd

# %%
df = pd.read_csv('/content/PRISMA Grey Literature - GitHub.csv')

# %%
df.shape
# Out:
# (2072, 8)

# %%
df.head()
# Out:
#          type                                              query  \
# 0  repository  "open source" "AI" "security" stars:>50 in:nam...
# 1  repository  "open source" "AI" "security" stars:>50 in:nam...
# 2  repository  "open source" "AI" "security" stars:>50 in:nam...
# 3  repository  "open source" "AI" "security" stars:>50 in:nam...
# 4  repository  "open source" "AI" "secure" stars:>50 in:name,...
#
#                                     name  \
# 0                          ollama/ollama
# 1                   langflow-ai/langflow
# 2                        langgenius/dify
# 3                  open-webui/open-webui
# 4  microsoft/generative-ai-for-beginners
#
#                                                  url  \
# 0                   https://github.com/ollama/ollama
# 1            https://github.com/langflow-ai/langflow
# 2                 https://github.com/langgenius/dify
# 3           https://github.com/open-webui/open-webui
# 4  https://github.com/microsoft/generative-ai-for...
#
#                                          description     stars  \
# 0  Get up and running with OpenAI gpt-oss, DeepSe...  157794.0
# 1  Langflow is a powerful tool for building and d...  141368.0
# 2  Production-ready platform for agentic workflow...  121990.0
# 3  User-friendly AI Interface (Supports Ollama, O...  118050.0
# 4  21 Lessons, Get Started Building with Generati...  103933.0
#
#            language                  date
# 0                Go  2025-12-17T14:39:14Z
# 1            Python  2025-12-17T15:02:57Z
# 2        TypeScript  2025-12-17T15:01:35Z
# 3            Svelte  2025-12-17T14:27:03Z
# 4  Jupyter Notebook  2025-12-17T14:47:37Z

# %%
df.isna().sum()
# Out:
# type            0
# query           0
# name            0
# url             0
# description     0
# stars          12
# language       12
# date           12
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.shape
# Out:
# (2060, 8)

# %%
df2['text_all'] = (
    df2['name'].fillna('') + ' ' +
    df2['description'].fillna('')
).str.lower()
#+ ' ' +
    #df2['query'].fillna('')
# Out:
# /tmp/ipykernel_683/294186043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text_all'] = (

# %%
# AI-related keywords
ai_keywords = [
    "ai", "artificial intelligence",
    "machine learning", "ml",
    "deep learning",
    "neural network", "neural networks",
    "large language model", "llm",
    "generative ai",
    "foundation model"
]

# Security-related keywords
security_keywords = [
    "security", "secure",
    "vulnerability", "vulnerabilities", "vulnerable",
    "exploit", "attacker", "attackers", "attack", "attacks",
    "adversarial",           # often used in "adversarial attacks"
    "penetration testing", "pentest", "pen-test",
    "malware", "threat", "threats",
    "xss", "sql injection", "csrf",
    "injection",
    "privilege escalation",
    "red team",
    "defense", "defence",
    "hardening",
    "cybersecurity", "cyber security",
    "infosec",
    "security auditing", "security audit", "security tool",
    "cve", "cvss"
]

# %%
def make_pattern(keywords):
    parts = []
    for k in keywords:
        k_ = k.replace(" ", r"\s+")
        parts.append(r"\b" + k_ + r"\b")
    pattern = "(?:" + "|".join(parts) + ")"
    return pattern

# %%
ai_pattern = make_pattern(ai_keywords)
security_pattern = make_pattern(security_keywords)

# %%
df2['is_ai'] = df2['text_all'].str.contains(ai_pattern, regex=True, na=False)
df2['is_security'] = df2['text_all'].str.contains(security_pattern, regex=True, na=False)

df2['is_ai'].value_counts(), df2['is_security'].value_counts()
# Out:
# /tmp/ipykernel_683/1154363465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['is_ai'] = df2['text_all'].str.contains(ai_pattern, regex=True, na=False)
# /tmp/ipykernel_683/1154363465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['is_security'] = df2['text_all'].str.contains(security_pattern, regex=True, na=False)
# (is_ai
#  False    1212
#  True      848
#  Name: count, dtype: int64,
#  is_security
#  False    1779
#  True      281
#  Name: count, dtype: int64)

# %%
df2['is_intersection'] = df2['is_ai'] & df2['is_security']
intersection_df = df2[df2['is_intersection']]

len(intersection_df), len(df2)
# Out:
# /tmp/ipykernel_683/443220505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['is_intersection'] = df2['is_ai'] & df2['is_security']
# (131, 2060)

# %%
intersection_df.duplicated(subset='name').sum()
# Out:
# np.int64(0)

# %%
intersection_df = df2[df2['is_intersection']].copy()

# %%
unique_df = intersection_df.drop_duplicates(subset='name', keep='first').reset_index(drop=True)

# %%
unique_df
# Out:
#            type                                              query  \
# 0    repository  "open source" "AI" "secure" stars:>50 in:name,...
# 1    repository  "open source" "AI" "secure" stars:>50 in:name,...
# 2    repository  "open source" "AI" "security" stars:>50 in:nam...
# 3    repository  "open source" "AI" "security" stars:>50 in:nam...
# 4    repository  "open source" "AI" "security" stars:>50 in:nam...
# ..          ...                                                ...
# 126  repository  "open source" "AI" "threat" stars:>50 in:name,...
# 127  repository  "open source" "LLM" "security" stars:>50 in:na...
# 128  repository  "open source" "large language model" "security...
# 129  repository  "open source" "machine learning" "secure" star...
# 130  repository  "open source" "large language model" "adversar...
#
#                             name  \
# 0              daytonaio/daytona
# 1          danny-avila/LibreChat
# 2                 usestrix/strix
# 3    microsoft/mcp-for-beginners
# 4            promptfoo/promptfoo
# ..                           ...
# 126              82ch/MCP-Dandan
# 127         aomail-ai/aomail-app
# 128      datasec-lab/CodeBreaker
# 129             AI-secure/aug-pe
# 130           user1342/Oversight
#
#                                                 url  \
# 0              https://github.com/daytonaio/daytona
# 1          https://github.com/danny-avila/LibreChat
# 2                 https://github.com/usestrix/strix
# 3    https://github.com/microsoft/mcp-for-beginners
# 4            https://github.com/promptfoo/promptfoo
# ..                                              ...
# 126              https://github.com/82ch/MCP-Dandan
# 127         https://github.com/aomail-ai/aomail-app
# 128      https://github.com/datasec-lab/CodeBreaker
# 129             https://github.com/AI-secure/aug-pe
# 130           https://github.com/user1342/Oversight
#
#                                            description    stars  \
# 0    Daytona is a Secure and Elastic Infrastructure...  37972.0
# 1    Enhanced ChatGPT Clone: Features Agents, MCP, ...  32487.0
# 2        Open-source AI agents for penetration testing  17918.0
# 3    This open-source curriculum introduces the fun...  13737.0
# 4    Test your prompts, agents, and RAGs. AI Red te...   9457.0
# ..                                                 ...      ...
# 126  MCP Security Solution for Agentic AI — real-...     54.0
# 127  Aomail is an AI interface that connects to Gma...     54.0
# 128  [USENIX Security '24] An LLM-Assisted Easy-to-...     53.0
# 129  [ICML 2024 Spotlight] Differentially Private S...     52.0
# 130  A Completely Modular LLM Reverse Engineering, ...     52.0
#
#              language                  date  \
# 0          TypeScript  2025-12-17T15:00:02Z
# 1          TypeScript  2025-12-17T14:55:52Z
# 2              Python  2025-12-17T14:57:16Z
# 3    Jupyter Notebook  2025-12-17T12:29:14Z
# 4          TypeScript  2025-12-17T14:56:34Z
# ..                ...                   ...
# 126            Python  2025-12-17T11:09:20Z
# 127               Vue  2025-12-09T21:57:19Z
# 128            Python  2025-11-18T01:23:09Z
# 129            Python  2025-12-10T22:32:18Z
# 130            Python  2025-10-19T15:20:53Z
#
#                                               text_all  is_ai  is_security  \
# 0    daytonaio/daytona daytona is a secure and elas...   True         True
# 1    danny-avila/librechat enhanced chatgpt clone: ...   True         True
# 2    usestrix/strix open-source ai agents for penet...   True         True
# 3    microsoft/mcp-for-beginners this open-source c...   True         True
# 4    promptfoo/promptfoo test your prompts, agents,...   True         True
# ..                                                 ...    ...          ...
# 126  82ch/mcp-dandan mcp security solution for agen...   True         True
# 127  aomail-ai/aomail-app aomail is an ai interface...   True         True
# 128  datasec-lab/codebreaker [usenix security '24] ...   True         True
# 129  ai-secure/aug-pe [icml 2024 spotlight] differe...   True         True
# 130  user1342/oversight a completely modular llm re...   True         True
#
#      is_intersection
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 126             True
# 127             True
# 128             True
# 129             True
# 130             True
#
# [131 rows x 12 columns]

# %%
unique_df['stars'] = unique_df['stars'].astype(int)

# %%
unique_df
# Out:
#            type                                              query  \
# 0    repository  "open source" "AI" "secure" stars:>50 in:name,...
# 1    repository  "open source" "AI" "secure" stars:>50 in:name,...
# 2    repository  "open source" "AI" "security" stars:>50 in:nam...
# 3    repository  "open source" "AI" "security" stars:>50 in:nam...
# 4    repository  "open source" "AI" "security" stars:>50 in:nam...
# ..          ...                                                ...
# 126  repository  "open source" "AI" "threat" stars:>50 in:name,...
# 127  repository  "open source" "LLM" "security" stars:>50 in:na...
# 128  repository  "open source" "large language model" "security...
# 129  repository  "open source" "machine learning" "secure" star...
# 130  repository  "open source" "large language model" "adversar...
#
#                             name  \
# 0              daytonaio/daytona
# 1          danny-avila/LibreChat
# 2                 usestrix/strix
# 3    microsoft/mcp-for-beginners
# 4            promptfoo/promptfoo
# ..                           ...
# 126              82ch/MCP-Dandan
# 127         aomail-ai/aomail-app
# 128      datasec-lab/CodeBreaker
# 129             AI-secure/aug-pe
# 130           user1342/Oversight
#
#                                                 url  \
# 0              https://github.com/daytonaio/daytona
# 1          https://github.com/danny-avila/LibreChat
# 2                 https://github.com/usestrix/strix
# 3    https://github.com/microsoft/mcp-for-beginners
# 4            https://github.com/promptfoo/promptfoo
# ..                                              ...
# 126              https://github.com/82ch/MCP-Dandan
# 127         https://github.com/aomail-ai/aomail-app
# 128      https://github.com/datasec-lab/CodeBreaker
# 129             https://github.com/AI-secure/aug-pe
# 130           https://github.com/user1342/Oversight
#
#                                            description  stars  \
# 0    Daytona is a Secure and Elastic Infrastructure...  37972
# 1    Enhanced ChatGPT Clone: Features Agents, MCP, ...  32487
# 2        Open-source AI agents for penetration testing  17918
# 3    This open-source curriculum introduces the fun...  13737
# 4    Test your prompts, agents, and RAGs. AI Red te...   9457
# ..                                                 ...    ...
# 126  MCP Security Solution for Agentic AI — real-...     54
# 127  Aomail is an AI interface that connects to Gma...     54
# 128  [USENIX Security '24] An LLM-Assisted Easy-to-...     53
# 129  [ICML 2024 Spotlight] Differentially Private S...     52
# 130  A Completely Modular LLM Reverse Engineering, ...     52
#
#              language                  date  \
# 0          TypeScript  2025-12-17T15:00:02Z
# 1          TypeScript  2025-12-17T14:55:52Z
# 2              Python  2025-12-17T14:57:16Z
# 3    Jupyter Notebook  2025-12-17T12:29:14Z
# 4          TypeScript  2025-12-17T14:56:34Z
# ..                ...                   ...
# 126            Python  2025-12-17T11:09:20Z
# 127               Vue  2025-12-09T21:57:19Z
# 128            Python  2025-11-18T01:23:09Z
# 129            Python  2025-12-10T22:32:18Z
# 130            Python  2025-10-19T15:20:53Z
#
#                                               text_all  is_ai  is_security  \
# 0    daytonaio/daytona daytona is a secure and elas...   True         True
# 1    danny-avila/librechat enhanced chatgpt clone: ...   True         True
# 2    usestrix/strix open-source ai agents for penet...   True         True
# 3    microsoft/mcp-for-beginners this open-source c...   True         True
# 4    promptfoo/promptfoo test your prompts, agents,...   True         True
# ..                                                 ...    ...          ...
# 126  82ch/mcp-dandan mcp security solution for agen...   True         True
# 127  aomail-ai/aomail-app aomail is an ai interface...   True         True
# 128  datasec-lab/codebreaker [usenix security '24] ...   True         True
# 129  ai-secure/aug-pe [icml 2024 spotlight] differe...   True         True
# 130  user1342/oversight a completely modular llm re...   True         True
#
#      is_intersection
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 126             True
# 127             True
# 128             True
# 129             True
# 130             True
#
# [131 rows x 12 columns]

# %%
unique_df.to_csv("github_filtered.csv", index=False)
from google.colab import files
files.download("github_filtered.csv")
